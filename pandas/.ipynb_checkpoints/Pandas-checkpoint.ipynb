# %%
import pandas as pd

# %% [markdown]
# ### Series

# %%
car_make = pd.Series(['Toyota', 'Lamborgini', 'Volkswagen', 'Nissan', 'Tata', 'Buggati', 'Ferrari'])

# %%
car_make
# Out:
# 0        Toyota
# 1    Lamborgini
# 2    Volkswagen
# 3        Nissan
# 4          Tata
# 5       Buggati
# 6       Ferrari
# dtype: object

# %%
color = pd.Series(['Blue', 'White', 'Black', 'Red', 'Silver', 'Matte', 'Orange'])

# %%
color
# Out:
# 0      Blue
# 1     White
# 2     Black
# 3       Red
# 4    Silver
# 5     Matte
# 6    Orange
# dtype: object

# %% [markdown]
# ### DataFrame

# %%
collection_of_cars = pd.DataFrame({'Car Make': car_make, 'Color': color})
collection_of_cars
# Out:
#      Car Make   Color
# 0      Toyota    Blue
# 1  Lamborgini   White
# 2  Volkswagen   Black
# 3      Nissan     Red
# 4        Tata  Silver
# 5     Buggati   Matte
# 6     Ferrari  Orange

# %% [markdown]
# ### Import a CSV file

# %%
# Importing a excel file from local storage

# %%
data = pd.read_csv("car-sales.csv")

# %%
data
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00
# 7   Honda   Blue          54738      4   $7,000.00
# 8  Toyota  White          60000      4   $6,250.00
# 9  Nissan  White          31600      4   $9,700.00

# %% [markdown]
# ### Export a CSV file

# %%
data.to_csv('exported-car-sales.csv', index=False)

# %%
get_exported_data = pd.read_csv('exported-car-sales.csv')
get_exported_data
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00
# 7   Honda   Blue          54738      4   $7,000.00
# 8  Toyota  White          60000      4   $6,250.00
# 9  Nissan  White          31600      4   $9,700.00

# %% [markdown]
# ## Describe Data

# %%
data.dtypes
# Out:
# Make             object
# Colour           object
# Odometer (KM)     int64
# Doors             int64
# Price            object
# dtype: object

# %%
columns = pd.Series(data.columns)

# %%
columns
# Out:
# 0             Make
# 1           Colour
# 2    Odometer (KM)
# 3            Doors
# 4            Price
# dtype: object

# %%
data
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00
# 7   Honda   Blue          54738      4   $7,000.00
# 8  Toyota  White          60000      4   $6,250.00
# 9  Nissan  White          31600      4   $9,700.00

# %%
data.describe()
# Out:
#        Odometer (KM)      Doors
# count      10.000000  10.000000
# mean    78601.400000   4.000000
# std     61983.471735   0.471405
# min     11179.000000   3.000000
# 25%     35836.250000   4.000000
# 50%     57369.000000   4.000000
# 75%     96384.500000   4.000000
# max    213095.000000   5.000000

# %%
data.mean()
# Out:
# Odometer (KM)    78601.4
# Doors                4.0
# dtype: float64

# %%
data["Doors"].max()
# Out:
# 5

# %%
data
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00
# 7   Honda   Blue          54738      4   $7,000.00
# 8  Toyota  White          60000      4   $6,250.00
# 9  Nissan  White          31600      4   $9,700.00

# %%
data.dtypes
# Out:
# Make             object
# Colour           object
# Odometer (KM)     int64
# Doors             int64
# Price            object
# dtype: object

# %%
data["Odometer (KM)"].sum()
# Out:
# 786014

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 5 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Make           10 non-null     object
#  1   Colour         10 non-null     object
#  2   Odometer (KM)  10 non-null     int64
#  3   Doors          10 non-null     int64
#  4   Price          10 non-null     object
# dtypes: int64(2), object(3)
# memory usage: 528.0+ bytes

# %%
data.Make[0] == "Toyota"
# Out:
# True

# %% [markdown]
# ## Selecting and Viewing Data

# %% [markdown]
# #### iloc and loc

# %%
color
# Out:
# 0      Blue
# 1     White
# 2     Black
# 3       Red
# 4    Silver
# 5     Matte
# 6    Orange
# dtype: object

# %%
data.iloc[9]
# Out:
# Make                Nissan
# Colour               White
# Odometer (KM)        31600
# Doors                    4
# Price            $9,700.00
# Name: 9, dtype: object

# %%
# head and tail

# %%
data.head(2)
# Out:
#      Make Colour  Odometer (KM)  Doors      Price
# 0  Toyota  White         150043      4  $4,000.00
# 1   Honda    Red          87899      4  $5,000.00

# %%
data.tail(3)
# Out:
#      Make Colour  Odometer (KM)  Doors      Price
# 7   Honda   Blue          54738      4  $7,000.00
# 8  Toyota  White          60000      4  $6,250.00
# 9  Nissan  White          31600      4  $9,700.00

# %%
data[data["Doors"] > 3]
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00
# 7   Honda   Blue          54738      4   $7,000.00
# 8  Toyota  White          60000      4   $6,250.00
# 9  Nissan  White          31600      4   $9,700.00

# %%
# crosstab
pd.crosstab(data['Make'], data['Doors'])
# Out:
# Doors   3  4  5
# Make
# BMW     0  0  1
# Honda   0  3  0
# Nissan  0  2  0
# Toyota  1  3  0

# %%
# groupby
data.groupby(['Make']).mean()
# Out:
#         Odometer (KM)  Doors
# Make
# BMW      11179.000000   5.00
# Honda    62778.333333   4.00
# Nissan  122347.500000   4.00
# Toyota   85451.250000   3.75

# %%
# .plot
data["Doors"].plot()

# %%
# .hist
data['Odometer (KM)'].hist()

# %%
data
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00
# 7   Honda   Blue          54738      4   $7,000.00
# 8  Toyota  White          60000      4   $6,250.00
# 9  Nissan  White          31600      4   $9,700.00

# %%
data['Price'] = (data['Price'].str.replace('[\$\,\.]', '', regex=True).astype(int) / 100).astype(int)

# %%
data
# Out:
#      Make Colour  Odometer (KM)  Doors  Price
# 0  Toyota  White         150043      4   4000
# 1   Honda    Red          87899      4   5000
# 2  Toyota   Blue          32549      3   7000
# 3     BMW  Black          11179      5  22000
# 4  Nissan  White         213095      4   3500
# 5  Toyota  Green          99213      4   4500
# 6   Honda   Blue          45698      4   7500
# 7   Honda   Blue          54738      4   7000
# 8  Toyota  White          60000      4   6250
# 9  Nissan  White          31600      4   9700

# %%
data['Price'].plot()

# %% [markdown]
# ### Manipulating Data

# %%
# Let's see over missing data

# %%
missing_data = pd.read_csv('car-sales-missing-data.csv')

# %%
missing_data
# Out:
#      Make Colour  Odometer  Doors    Price
# 0  Toyota  White  150043.0    4.0   $4,000
# 1   Honda    Red   87899.0    4.0   $5,000
# 2  Toyota   Blue       NaN    3.0   $7,000
# 3     BMW  Black   11179.0    5.0  $22,000
# 4  Nissan  White  213095.0    4.0   $3,500
# 5  Toyota  Green       NaN    4.0   $4,500
# 6   Honda    NaN       NaN    4.0   $7,500
# 7   Honda   Blue       NaN    4.0      NaN
# 8  Toyota  White   60000.0    NaN      NaN
# 9     NaN  White   31600.0    4.0   $9,700

# %%
# fillna
missing_data['Odometer'].fillna(missing_data['Odometer'].mean(), inplace=True)

# %%
missing_data
# Out:
#      Make Colour       Odometer  Doors    Price
# 0  Toyota  White  150043.000000    4.0   $4,000
# 1   Honda    Red   87899.000000    4.0   $5,000
# 2  Toyota   Blue   92302.666667    3.0   $7,000
# 3     BMW  Black   11179.000000    5.0  $22,000
# 4  Nissan  White  213095.000000    4.0   $3,500
# 5  Toyota  Green   92302.666667    4.0   $4,500
# 6   Honda    NaN   92302.666667    4.0   $7,500
# 7   Honda   Blue   92302.666667    4.0      NaN
# 8  Toyota  White   60000.000000    NaN      NaN
# 9     NaN  White   31600.000000    4.0   $9,700

# %%
dropped_missing_data = missing_data.dropna()

# %%
dropped_missing_data.to_csv('refined-car-sales-data.csv')

# %%
# add columns
data['Mileage'] = pd.Series([23,42,53,24,64])
data
# Out:
#      Make Colour  Odometer (KM)  Doors  Price  Mileage
# 0  Toyota  White         150043      4   4000     23.0
# 1   Honda    Red          87899      4   5000     42.0
# 2  Toyota   Blue          32549      3   7000     53.0
# 3     BMW  Black          11179      5  22000     24.0
# 4  Nissan  White         213095      4   3500     64.0
# 5  Toyota  Green          99213      4   4500      NaN
# 6   Honda   Blue          45698      4   7500      NaN
# 7   Honda   Blue          54738      4   7000      NaN
# 8  Toyota  White          60000      4   6250      NaN
# 9  Nissan  White          31600      4   9700      NaN

# %%
data.fillna(50, inplace=True)
# Out:
#      Make Colour  Odometer (KM)  Doors  Price  Mileage
# 0  Toyota  White         150043      4   4000     23.0
# 1   Honda    Red          87899      4   5000     42.0
# 2  Toyota   Blue          32549      3   7000     53.0
# 3     BMW  Black          11179      5  22000     24.0
# 4  Nissan  White         213095      4   3500     64.0
# 5  Toyota  Green          99213      4   4500     50.0
# 6   Honda   Blue          45698      4   7500     50.0
# 7   Honda   Blue          54738      4   7000     50.0
# 8  Toyota  White          60000      4   6250     50.0
# 9  Nissan  White          31600      4   9700     50.0

# %%
# column from python list
#### Left because it needs data to be entered manually to the length of the rows in the Dataframe.
# add data using one assignment !
data['Seats'] = 5
data
# Out:
#      Make Colour  Odometer (KM)  Doors  Price  Mileage  Seats
# 0  Toyota  White         150043      4   4000     23.0      5
# 1   Honda    Red          87899      4   5000     42.0      5
# 2  Toyota   Blue          32549      3   7000     53.0      5
# 3     BMW  Black          11179      5  22000     24.0      5
# 4  Nissan  White         213095      4   3500     64.0      5
# 5  Toyota  Green          99213      4   4500     50.0      5
# 6   Honda   Blue          45698      4   7500     50.0      5
# 7   Honda   Blue          54738      4   7000     50.0      5
# 8  Toyota  White          60000      4   6250     50.0      5
# 9  Nissan  White          31600      4   9700     50.0      5

# %%
data['Total Fuel Consumed'] = data['Odometer (KM)'] / data['Mileage']

# %%
data
# Out:
#      Make Colour  Odometer (KM)  Doors  Price  Mileage  Seats  \
# 0  Toyota  White         150043      4   4000     23.0      5
# 1   Honda    Red          87899      4   5000     42.0      5
# 2  Toyota   Blue          32549      3   7000     53.0      5
# 3     BMW  Black          11179      5  22000     24.0      5
# 4  Nissan  White         213095      4   3500     64.0      5
# 5  Toyota  Green          99213      4   4500     50.0      5
# 6   Honda   Blue          45698      4   7500     50.0      5
# 7   Honda   Blue          54738      4   7000     50.0      5
# 8  Toyota  White          60000      4   6250     50.0      5
# 9  Nissan  White          31600      4   9700     50.0      5
#
#    Total Fuel Consumed
# 0          6523.608696
# 1          2092.833333
# 2           614.132075
# 3           465.791667
# 4          3329.609375
# 5          1984.260000
# 6           913.960000
# 7          1094.760000
# 8          1200.000000
# 9           632.000000

# %%
data.loc[0,'Seats'] = 4

# %%
data
# Out:
#      Make Colour  Odometer (KM)  Doors  Price  Mileage  Seats  \
# 0  Toyota  White         150043      4   4000     23.0      4
# 1   Honda    Red          87899      4   5000     42.0      5
# 2  Toyota   Blue          32549      3   7000     53.0      5
# 3     BMW  Black          11179      5  22000     24.0      5
# 4  Nissan  White         213095      4   3500     64.0      5
# 5  Toyota  Green          99213      4   4500     50.0      5
# 6   Honda   Blue          45698      4   7500     50.0      5
# 7   Honda   Blue          54738      4   7000     50.0      5
# 8  Toyota  White          60000      4   6250     50.0      8
# 9  Nissan  White          31600      4   9700     50.0      5
#
#    Total Fuel Consumed
# 0          6523.608696
# 1          2092.833333
# 2           614.132075
# 3           465.791667
# 4          3329.609375
# 5          1984.260000
# 6           913.960000
# 7          1094.760000
# 8          1200.000000
# 9           632.000000

# %%
# Shuffle the pattern that data is received !
data = data.sample(frac=1)
data
# Out:
#      Make Colour  Odometer (KM)  Doors  Price  Mileage  Seats  \
# 6   Honda    Red          87899      4   5000     42.0      5
# 0     BMW  Black          11179      5  22000     24.0      5
# 9  Nissan  White          31600      4   9700     50.0      5
# 5   Honda   Blue          54738      4   7000     50.0      5
# 2   Honda   Blue          45698      4   7500     50.0      5
# 1  Toyota  White          60000      4   6250     50.0      8
# 8  Nissan  White         213095      4   3500     64.0      5
# 7  Toyota  Green          99213      4   4500     50.0      5
# 4  Toyota  White         150043      4   4000     23.0      4
# 3  Toyota   Blue          32549      3   7000     53.0      5
#
#    Total Fuel Consumed
# 6          2092.833333
# 0           465.791667
# 9           632.000000
# 5          1094.760000
# 2           913.960000
# 1          1200.000000
# 8          3329.609375
# 7          1984.260000
# 4          6523.608696
# 3           614.132075

# %%
# Revert back
data = data.reset_index(drop=True)
